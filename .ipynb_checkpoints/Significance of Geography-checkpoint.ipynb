# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Prepare the dataframe by opening the file in excel, and delete the first column called "Row Columns"

# %%
dma_path = f"Resources/BR _ Revlimid - HCP - DMA.xlsx"
dma_df = pd.read_excel(dma_path, encoding="utf-8")
dma_df.fillna("None")
# Out:
#        Cost  Clicks  Impr Cost/wt action  Weighted actions  \
# 0    331.05      68   592        2.90395               114
# 1    173.16      33   279        2.98552                58
# 2    263.88      58   477        3.88059                68
# 3     63.10      12   120        4.20667                15
# 4     26.33       6   102        2.92556                 9
# ..      ...     ...   ...            ...               ...
# 206   51.91      12    68        2.88389                18
# 207  129.29      24   304        2.93841                44
# 208   65.86      17   145        2.19533                30
# 209   20.23       4    46        3.37167                 6
# 210    0.00       0    11           None                 0
#
#               DMA Region name DMA region ID  Avg CPC       CTR Avg pos
# 0         Portland-Auburn, ME        200500  4.86838  0.114865    None
# 1      South Bend-Elkhart, IN        200588  5.24727  0.118280    None
# ...
